# %%
import rasterio
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from pathlib import Path

# %% [markdown]
# # 3.1. Elección de variables predictoras

# %% [markdown]
# # 3.2. ¿Qué representa cada predictor?

# %% [markdown]
# **x**: Representa la posición horizontal (longitud) de un píxel.
#
# **y**: Representa la posición vertical (latitud) de un píxel.
#
# Las dos anteriores han sido para la localización de los objetos en las imágenes. Las siguientes están asociadas a los espectros.
#
# **NDVI**: Está asociado a la vegetación o a la fotosíntesis, fenómeno que nos interesa en este caso por su relación con la cianobacteria.
#
# **NDWI**: Índice asociado a la presencia de cuerpos de agua. Este se elige porque puede ser de ayuda para caracterizar las condiciones de la superficie del agua y sus diferencias respecto a regiones con presencia de floración de cianobacteria

# %% [markdown]
# # 3.3. Ingeniería de caaracterísticas

# %% [markdown]
# Por medio de ingeniería de caracerísticas se propone la realización de funciones
